# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

# %%
df = pd.read_csv('AXISBANK.csv')

# %%
df.head()
# Out:
#          Date   Symbol Series  Prev Close  Open   High    Low  Last  Close  \
# 0  2000-01-03  UTIBANK     EQ       24.70  26.7  26.70  26.70  26.7  26.70
# 1  2000-01-04  UTIBANK     EQ       26.70  27.0  28.70  26.50  27.0  26.85
# 2  2000-01-05  UTIBANK     EQ       26.85  26.0  27.75  25.50  26.4  26.30
# 3  2000-01-06  UTIBANK     EQ       26.30  25.8  27.00  25.80  25.9  25.95
# 4  2000-01-07  UTIBANK     EQ       25.95  25.0  26.00  24.25  25.0  24.80
#
#     VWAP  Volume      Turnover  Trades  Deliverable Volume  %Deliverble
# 0  26.70  112100  2.993070e+11     NaN                 NaN          NaN
# 1  27.24  234500  6.387275e+11     NaN                 NaN          NaN
# 2  26.24  170100  4.462980e+11     NaN                 NaN          NaN
# 3  26.27  102100  2.681730e+11     NaN                 NaN          NaN
# 4  25.04   62600  1.567220e+11     NaN                 NaN          NaN

# %%
df.shape
# Out:
# (5204, 15)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5204 entries, 0 to 5203
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5204 non-null   object
#  1   Symbol              5204 non-null   object
#  2   Series              5204 non-null   object
#  3   Prev Close          5204 non-null   float64
#  4   Open                5204 non-null   float64
#  5   High                5204 non-null   float64
#  6   Low                 5204 non-null   float64
#  7   Last                5204 non-null   float64
#  8   Close               5204 non-null   float64
#  9   VWAP                5204 non-null   float64
#  10  Volume              5204 non-null   int64
#  11  Turnover            5204 non-null   float64
#  12  Trades              2354 non-null   float64
#  13  Deliverable Volume  4695 non-null   float64
#  14  %Deliverble         4695 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 610.0+ KB

# %%
df.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count  5204.000000  5204.000000  5204.000000  5204.000000  5204.000000
# mean    583.860002   584.600029   594.549039   573.677219   583.975942
# std     440.698723   440.583630   447.085962   434.030670   440.589453
# min      22.150000    21.000000    23.700000    21.000000    22.150000
# 25%     227.200000   227.500000   231.987500   222.212500   227.537500
# 50%     514.125000   515.000000   521.950000   507.075000   514.025000
# 75%     905.262500   905.212500   920.200000   882.087500   903.475000
# max    2023.350000  2034.400000  2043.050000  2002.600000  2022.550000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count  5204.000000  5204.000000  5.204000e+03  5.204000e+03    2354.000000
# mean    583.970859   584.163178  4.256712e+06  2.546893e+14  115971.124044
# std     440.630594   440.593933  7.851790e+06  3.832740e+14   93740.136590
# min      22.150000    22.170000  2.850000e+03  8.275250e+09    2698.000000
# 25%     227.537500   227.757500  2.719952e+05  5.293304e+12   61330.250000
# 50%     514.200000   515.060000  1.577827e+06  1.605226e+14   90068.000000
# 75%     905.262500   903.617500  5.145555e+06  3.333198e+14  137473.250000
# max    2023.350000  2020.310000  1.205419e+08  7.179550e+15  990737.000000
#
#        Deliverable Volume  %Deliverble
# count        4.695000e+03  4695.000000
# mean         1.902423e+06     0.470017
# std          3.209449e+06     0.161909
# min          5.809000e+03     0.075000
# 25%          2.495475e+05     0.352850
# 50%          7.409520e+05     0.463600
# 75%          2.475333e+06     0.577600
# max          9.490116e+07     0.983000

# %%
df.columns
# Out:
# Index(['Date', 'Symbol', 'Series', 'Prev Close', 'Open', 'High', 'Low', 'Last',
#        'Close', 'VWAP', 'Volume', 'Turnover', 'Trades', 'Deliverable Volume',
#        '%Deliverble'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Date                     0
# Symbol                   0
# Series                   0
# Prev Close               0
# Open                     0
# High                     0
# Low                      0
# Last                     0
# Close                    0
# VWAP                     0
# Volume                   0
# Turnover                 0
# Trades                2850
# Deliverable Volume     509
# %Deliverble            509
# dtype: int64

# %%
# !pip install missingno
# Out:
# Requirement already satisfied: missingno in c:\users\priya\anaconda3\lib\site-packages (0.5.2)
# Requirement already satisfied: numpy in c:\users\priya\anaconda3\lib\site-packages (from missingno) (1.23.5)
# Requirement already satisfied: matplotlib in c:\users\priya\anaconda3\lib\site-packages (from missingno) (3.5.2)
# Requirement already satisfied: scipy in c:\users\priya\anaconda3\lib\site-packages (from missingno) (1.9.1)
# Requirement already satisfied: seaborn in c:\users\priya\anaconda3\lib\site-packages (from missingno) (0.11.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->missingno) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->missingno) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->missingno) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->missingno) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->missingno) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->missingno) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\priya\anaconda3\lib\site-packages (from matplotlib->missingno) (21.3)
# Requirement already satisfied: pandas>=0.23 in c:\users\priya\anaconda3\lib\site-packages (from seaborn->missingno) (1.4.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\priya\anaconda3\lib\site-packages (from pandas>=0.23->seaborn->missingno) (2022.1)
# Requirement already satisfied: six>=1.5 in c:\users\priya\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->missingno) (1.16.0)

# %%
import missingno as msno
msno.matrix(df)
plt.xlabel('Missing Value Matrix')
plt.ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5204 entries, 0 to 5203
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                5204 non-null   object
#  1   Symbol              5204 non-null   object
#  2   Series              5204 non-null   object
#  3   Prev Close          5204 non-null   float64
#  4   Open                5204 non-null   float64
#  5   High                5204 non-null   float64
#  6   Low                 5204 non-null   float64
#  7   Last                5204 non-null   float64
#  8   Close               5204 non-null   float64
#  9   VWAP                5204 non-null   float64
#  10  Volume              5204 non-null   int64
#  11  Turnover            5204 non-null   float64
#  12  Trades              2354 non-null   float64
#  13  Deliverable Volume  4695 non-null   float64
#  14  %Deliverble         4695 non-null   float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 610.0+ KB

# %%
stockprice_one_year = df[(df['Date']>'2011-03-31')&(df['Date']<'2012-04-01')]
stockprice_one_year
# Out:
#             Date    Symbol Series  Prev Close     Open     High      Low  \
# 2810  2011-04-01  AXISBANK     EQ     1403.85  1410.30  1417.00  1378.60
# 2811  2011-04-04  AXISBANK     EQ     1407.75  1411.10  1441.90  1407.00
# 2812  2011-04-05  AXISBANK     EQ     1432.10  1448.00  1448.00  1409.10
# 2813  2011-04-06  AXISBANK     EQ     1424.75  1420.00  1441.70  1415.00
# 2814  2011-04-07  AXISBANK     EQ     1428.95  1430.00  1458.00  1416.70
# ...          ...       ...    ...         ...      ...      ...      ...
# 3054  2012-03-26  AXISBANK     EQ     1179.35  1174.90  1174.90  1120.00
# 3055  2012-03-27  AXISBANK     EQ     1125.15  1154.00  1161.00  1117.05
# 3056  2012-03-28  AXISBANK     EQ     1141.50  1130.00  1137.85  1108.25
# 3057  2012-03-29  AXISBANK     EQ     1115.60  1098.15  1137.60  1095.20
# 3058  2012-03-30  AXISBANK     EQ     1122.05  1132.50  1152.00  1130.00
#
#          Last    Close     VWAP   Volume      Turnover   Trades  \
# 2810  1411.00  1407.75  1396.75  1069318  1.493572e+14      NaN
# 2811  1434.00  1432.10  1428.13  1091468  1.558756e+14      NaN
# 2812  1419.05  1424.75  1423.09  1007374  1.433588e+14      NaN
# 2813  1432.00  1428.95  1428.26  1694291  2.419884e+14      NaN
# 2814  1447.45  1445.75  1441.81  1257062  1.812449e+14      NaN
# ...       ...      ...      ...      ...           ...      ...
# 3054  1126.00  1125.15  1137.88  2270885  2.583991e+14  86606.0
# 3055  1144.00  1141.50  1137.53  2947670  3.353065e+14  82279.0
# 3056  1113.00  1115.60  1122.85  1969080  2.210981e+14  66846.0
# 3057  1118.95  1122.05  1119.21  2738630  3.065114e+14  71029.0
# 3058  1144.00  1146.20  1143.61  2596538  2.969425e+14  72227.0
#
#       Deliverable Volume  %Deliverble
# 2810            326187.0       0.3050
# 2811            455298.0       0.4171
# 2812            375368.0       0.3726
# 2813            895446.0       0.5285
# 2814            501871.0       0.3992
# ...                  ...          ...
# 3054            871769.0       0.3839
# 3055            686528.0       0.2329
# 3056            661093.0       0.3357
# 3057            879897.0       0.3213
# 3058           1015516.0       0.3911
#
# [249 rows x 15 columns]

# %%
stockprice_one_year.isnull().sum()
# Out:
# Date                   0
# Symbol                 0
# Series                 0
# Prev Close             0
# Open                   0
# High                   0
# Low                    0
# Last                   0
# Close                  0
# VWAP                   0
# Volume                 0
# Turnover               0
# Trades                40
# Deliverable Volume     0
# %Deliverble            0
# dtype: int64

# %%
stockprice_one_year.describe()
# Out:
#         Prev Close         Open         High          Low         Last  \
# count   249.000000   249.000000   249.000000   249.000000   249.000000
# mean   1145.080723  1146.804016  1164.202008  1125.818072  1144.173896
# std     149.263051   148.426676   148.372394   148.410183   148.692814
# min     794.800000   805.100000   815.000000   784.000000   794.600000
# 25%    1049.700000  1055.300000  1078.000000  1029.450000  1047.000000
# 50%    1150.500000  1150.000000  1172.900000  1130.100000  1149.900000
# 75%    1244.650000  1247.350000  1264.900000  1226.400000  1245.650000
# max    1449.700000  1449.000000  1460.450000  1438.650000  1457.500000
#
#              Close         VWAP        Volume      Turnover         Trades  \
# count   249.000000   249.000000  2.490000e+02  2.490000e+02     209.000000
# mean   1144.045984  1144.483534  2.084293e+06  2.331558e+14   64363.181818
# std     148.352224   148.353504  9.509593e+05  1.013639e+14   24368.314321
# min     794.800000   796.020000  1.096870e+05  1.286282e+13    3447.000000
# 25%    1049.700000  1051.930000  1.419262e+06  1.642678e+14   48311.000000
# 50%    1150.000000  1149.830000  1.970083e+06  2.210981e+14   63750.000000
# 75%    1244.350000  1244.310000  2.621078e+06  2.861793e+14   79511.000000
# max    1449.700000  1447.850000  7.011924e+06  7.148659e+14  160890.000000
#
#        Deliverable Volume  %Deliverble
# count        2.490000e+02   249.000000
# mean         8.001602e+05     0.381518
# std          4.457195e+05     0.103180
# min          1.780300e+04     0.114400
# 25%          4.946110e+05     0.313600
# 50%          7.124760e+05     0.378100
# 75%          1.007798e+06     0.459100
# max          3.303235e+06     0.707000

# %%
stockprice_one_year.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 249 entries, 2810 to 3058
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                249 non-null    object
#  1   Symbol              249 non-null    object
#  2   Series              249 non-null    object
#  3   Prev Close          249 non-null    float64
#  4   Open                249 non-null    float64
#  5   High                249 non-null    float64
#  6   Low                 249 non-null    float64
#  7   Last                249 non-null    float64
#  8   Close               249 non-null    float64
#  9   VWAP                249 non-null    float64
#  10  Volume              249 non-null    int64
#  11  Turnover            249 non-null    float64
#  12  Trades              209 non-null    float64
#  13  Deliverable Volume  249 non-null    float64
#  14  %Deliverble         249 non-null    float64
# dtypes: float64(11), int64(1), object(3)
# memory usage: 31.1+ KB

# %%
pl = df['Prev Close'].plot(c='green')
stockprice_one_year['Prev Close'].plot(ax=pl,c='red')
# Out:
# <AxesSubplot:>

# %%
pl = df['Open'].plot(c='green')
stockprice_one_year['Open'].plot(ax=pl,c='red')
# Out:
# <AxesSubplot:>

# %%
pl = df['Last'].plot(c='green')
stockprice_one_year['Last'].plot(ax=pl,c='red')
# Out:
# <AxesSubplot:>

# %%
pl = df['Close'].plot(c='green')
stockprice_one_year['Close'].plot(ax=pl,c='red')
# Out:
# <AxesSubplot:>

# %%
pl = df['VWAP'].plot(c='green')
stockprice_one_year['VWAP'].plot(ax=pl,c='red')
# Out:
# <AxesSubplot:>

# %%
plt.plot(df['Open'])

# %%
plt.style.use('fivethirtyeight')
plt.plot(df['Open'])

# %%
df.corr()
# Out:
#                     Prev Close      Open      High       Low      Last  \
# Prev Close            1.000000  0.998548  0.998260  0.998195  0.997915
# Open                  0.998548  1.000000  0.999613  0.999564  0.999226
# High                  0.998260  0.999613  1.000000  0.999377  0.999653
# Low                   0.998195  0.999564  0.999377  1.000000  0.999576
# Last                  0.997915  0.999226  0.999653  0.999576  1.000000
# Close                 0.997970  0.999284  0.999685  0.999619  0.999980
# VWAP                  0.998292  0.999609  0.999822  0.999783  0.999837
# Volume                0.016882  0.016901  0.019095  0.015634  0.017722
# Turnover              0.179154  0.179585  0.182070  0.178468  0.180820
# Trades               -0.369206 -0.368672 -0.360524 -0.374685 -0.366852
# Deliverable Volume   -0.045789 -0.046212 -0.045525 -0.046815 -0.046140
# %Deliverble          -0.352406 -0.352306 -0.355550 -0.351097 -0.354459
#
#                        Close      VWAP    Volume  Turnover    Trades  \
# Prev Close          0.997970  0.998292  0.016882  0.179154 -0.369206
# Open                0.999284  0.999609  0.016901  0.179585 -0.368672
# High                0.999685  0.999822  0.019095  0.182070 -0.360524
# Low                 0.999619  0.999783  0.015634  0.178468 -0.374685
# Last                0.999980  0.999837  0.017722  0.180820 -0.366852
# Close               1.000000  0.999877  0.017620  0.180776 -0.367104
# VWAP                0.999877  1.000000  0.017428  0.180442 -0.367535
# Volume              0.017620  0.017428  1.000000  0.955833  0.905337
# Turnover            0.180776  0.180442  0.955833  1.000000  0.880220
# Trades             -0.367104 -0.367535  0.905337  0.880220  1.000000
# Deliverable Volume -0.046204 -0.046216  0.861349  0.869719  0.693777
# %Deliverble        -0.354403 -0.354052 -0.234796 -0.257512 -0.095324
#
#                     Deliverable Volume  %Deliverble
# Prev Close                   -0.045789    -0.352406
# Open                         -0.046212    -0.352306
# High                         -0.045525    -0.355550
# Low                          -0.046815    -0.351097
# Last                         -0.046140    -0.354459
# Close                        -0.046204    -0.354403
# VWAP                         -0.046216    -0.354052
# Volume                        0.861349    -0.234796
# Turnover                      0.869719    -0.257512
# Trades                        0.693777    -0.095324
# Deliverable Volume            1.000000    -0.019852
# %Deliverble                  -0.019852     1.000000

# %%
plt.figure(figsize=(25,15))
sns.heatmap(stockprice_one_year.corr(method='pearson'), annot=True)
# Out:
# <AxesSubplot:>

# %%
stockprice_one_year.plot(x='Date',y=['Low','High','Close','Open','Last'],color=['r','g','k','b','y'],figsize=[25,15])
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
stockprice_one_year.plot(x='Date',y=['Low','High'],color=['r','b'],figsize=[25,15])
plt.show()

# %%
stockprice_one_year.plot(x='Date',y=['Low','High'],color=['r','b'],figsize=[25,15])
plt.fill_between(stockprice_one_year['Date'],stockprice_one_year['Low'],stockprice_one_year['High'],color='k',alpha=0.5)
plt.show()

# %%
plt.figure(figsize=(25,15))
plt.boxplot(stockprice_one_year[['Close','High','Open','Low','VWAP']])
plt.show()

# %%
data = df[['Date','Open','High','Low','Volume','VWAP']]

# %%
df.set_index('Date',drop=False,inplace=True)

# %%
df.Close.plot(figsize=(14,7))
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5204 entries, 0 to 5203
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    5204 non-null   object
#  1   Open    5204 non-null   float64
#  2   High    5204 non-null   float64
#  3   Low     5204 non-null   float64
#  4   Volume  5204 non-null   int64
#  5   VWAP    5204 non-null   float64
# dtypes: float64(4), int64(1), object(1)
# memory usage: 244.1+ KB

# %%
df.reset_index(drop=True,inplace=True)
lag_features = ['Open','High','Low','VWAP']
window1= 3
window2= 7

df_rolled_3d = df[lag_features].rolling(window=window1,min_periods=0)
df_mean_3d = df_rolled_3d.mean().shift(1).reset_index().astype(np.float32)

df_rolled_7d = df[lag_features].rolling(window=window1,min_periods=0)
df_mean_7d = df_rolled_7d.mean().shift(1).reset_index().astype(np.float32)
                                                               
                                                               
                       
for feature in lag_features:
    df[f'{feature}_mean_lag{window1}'] = df_mean_3d[feature].astype('float32')
    df[f'{feature}_std_lag{window2}'] = df_mean_7d[feature].astype('float32')

# %%
df.fillna(df.mean(),inplace=True)

# %%
df.set_index('Date',drop=False,inplace=True)
df.head()
# Out:
#                   Date   Symbol Series  Prev Close  Open   High    Low  Last  \
# Date
# 2000-01-03  2000-01-03  UTIBANK     EQ       24.70  26.7  26.70  26.70  26.7
# 2000-01-04  2000-01-04  UTIBANK     EQ       26.70  27.0  28.70  26.50  27.0
# 2000-01-05  2000-01-05  UTIBANK     EQ       26.85  26.0  27.75  25.50  26.4
# 2000-01-06  2000-01-06  UTIBANK     EQ       26.30  25.8  27.00  25.80  25.9
# 2000-01-07  2000-01-07  UTIBANK     EQ       25.95  25.0  26.00  24.25  25.0
#
#             Close   VWAP  ...  Deliverable Volume  %Deliverble  \
# Date                      ...
# 2000-01-03  26.70  26.70  ...        1.902423e+06     0.470017
# 2000-01-04  26.85  27.24  ...        1.902423e+06     0.470017
# 2000-01-05  26.30  26.24  ...        1.902423e+06     0.470017
# 2000-01-06  25.95  26.27  ...        1.902423e+06     0.470017
# 2000-01-07  24.80  25.04  ...        1.902423e+06     0.470017
#
#             Open_mean_lag3  Open_std_lag7  High_mean_lag3  High_std_lag7  \
# Date
# 2000-01-03      584.483398     584.483398      594.429871     594.429871
# 2000-01-04       26.700001      26.700001       26.700001      26.700001
# 2000-01-05       26.850000      26.850000       27.700001      27.700001
# 2000-01-06       26.566668      26.566668       27.716667      27.716667
# 2000-01-07       26.266666      26.266666       27.816668      27.816668
#
#             Low_mean_lag3  Low_std_lag7  VWAP_mean_lag3  VWAP_std_lag7
# Date
# 2000-01-03     573.561707    573.561707      584.047913     584.047913
# 2000-01-04      26.700001     26.700001       26.700001      26.700001
# 2000-01-05      26.600000     26.600000       26.969999      26.969999
# 2000-01-06      26.233334     26.233334       26.726667      26.726667
# 2000-01-07      25.933332     25.933332       26.583334      26.583334
#
# [5 rows x 23 columns]

# %%
df.Date = pd.to_datetime(df.Date, format='%Y-%m-%d')
df['month'] = df.Date.dt.month
df['day'] = df.Date.dt.day
df['day_of_week'] = df.Date.dt.dayofweek
df.head()
# Out:
#                  Date   Symbol Series  Prev Close  Open   High    Low  Last  \
# Date
# 2000-01-03 2000-01-03  UTIBANK     EQ       24.70  26.7  26.70  26.70  26.7
# 2000-01-04 2000-01-04  UTIBANK     EQ       26.70  27.0  28.70  26.50  27.0
# 2000-01-05 2000-01-05  UTIBANK     EQ       26.85  26.0  27.75  25.50  26.4
# 2000-01-06 2000-01-06  UTIBANK     EQ       26.30  25.8  27.00  25.80  25.9
# 2000-01-07 2000-01-07  UTIBANK     EQ       25.95  25.0  26.00  24.25  25.0
#
#             Close   VWAP  ...  Open_std_lag7  High_mean_lag3  High_std_lag7  \
# Date                      ...
# 2000-01-03  26.70  26.70  ...     584.483398      594.429871     594.429871
# 2000-01-04  26.85  27.24  ...      26.700001       26.700001      26.700001
# 2000-01-05  26.30  26.24  ...      26.850000       27.700001      27.700001
# 2000-01-06  25.95  26.27  ...      26.566668       27.716667      27.716667
# 2000-01-07  24.80  25.04  ...      26.266666       27.816668      27.816668
#
#             Low_mean_lag3  Low_std_lag7  VWAP_mean_lag3  VWAP_std_lag7  month  \
# Date
# 2000-01-03     573.561707    573.561707      584.047913     584.047913      1
# 2000-01-04      26.700001     26.700001       26.700001      26.700001      1
# 2000-01-05      26.600000     26.600000       26.969999      26.969999      1
# 2000-01-06      26.233334     26.233334       26.726667      26.726667      1
# 2000-01-07      25.933332     25.933332       26.583334      26.583334      1
#
#             day  day_of_week
# Date
# 2000-01-03    3            0
# 2000-01-04    4            1
# 2000-01-05    5            2
# 2000-01-06    6            3
# 2000-01-07    7            4
#
# [5 rows x 26 columns]

# %%
df = df.drop(columns=['Symbol'])
df = df.drop(columns=['Series'])

# %%
df_train = df[df.Date < '2018']
df_valid = df[df.Date >= '2018']

# %%
df_valid.shape
# Out:
# (721, 24)

# %%
! pip install keras
import tensorflow
from sklearn.preprocessing import MinMaxScaler
# Out:
# Requirement already satisfied: keras in c:\users\priya\anaconda3\lib\site-packages (2.12.0)

# %%
df_train.head()
# Out:
#                  Date  Prev Close  Open   High    Low  Last  Close   VWAP  \
# Date
# 2000-01-03 2000-01-03       24.70  26.7  26.70  26.70  26.7  26.70  26.70
# 2000-01-04 2000-01-04       26.70  27.0  28.70  26.50  27.0  26.85  27.24
# 2000-01-05 2000-01-05       26.85  26.0  27.75  25.50  26.4  26.30  26.24
# 2000-01-06 2000-01-06       26.30  25.8  27.00  25.80  25.9  25.95  26.27
# 2000-01-07 2000-01-07       25.95  25.0  26.00  24.25  25.0  24.80  25.04
#
#             Volume      Turnover  ...  Open_std_lag7  High_mean_lag3  \
# Date                              ...
# 2000-01-03  112100  2.993070e+11  ...     584.483398      594.429871
# 2000-01-04  234500  6.387275e+11  ...      26.700001       26.700001
# 2000-01-05  170100  4.462980e+11  ...      26.850000       27.700001
# 2000-01-06  102100  2.681730e+11  ...      26.566668       27.716667
# 2000-01-07   62600  1.567220e+11  ...      26.266666       27.816668
#
#             High_std_lag7  Low_mean_lag3  Low_std_lag7  VWAP_mean_lag3  \
# Date
# 2000-01-03     594.429871     573.561707    573.561707      584.047913
# 2000-01-04      26.700001      26.700001     26.700001       26.700001
# 2000-01-05      27.700001      26.600000     26.600000       26.969999
# 2000-01-06      27.716667      26.233334     26.233334       26.726667
# 2000-01-07      27.816668      25.933332     25.933332       26.583334
#
#             VWAP_std_lag7  month  day  day_of_week
# Date
# 2000-01-03     584.047913      1    3            0
# 2000-01-04      26.700001      1    4            1
# 2000-01-05      26.969999      1    5            2
# 2000-01-06      26.726667      1    6            3
# 2000-01-07      26.583334      1    7            4
#
# [5 rows x 24 columns]

# %%
df_train.head().T
# Out:
# Date                         2000-01-03           2000-01-04  \
# Date                2000-01-03 00:00:00  2000-01-04 00:00:00
# Prev Close                         24.7                 26.7
# Open                               26.7                 27.0
# High                               26.7                 28.7
# Low                                26.7                 26.5
# Last                               26.7                 27.0
# Close                              26.7                26.85
# VWAP                               26.7                27.24
# Volume                           112100               234500
# Turnover                 299307000000.0       638727500000.0
# Trades                    115971.124044        115971.124044
# Deliverable Volume       1902423.307774       1902423.307774
# %Deliverble                    0.470017             0.470017
# Open_mean_lag3               584.483398            26.700001
# Open_std_lag7                584.483398            26.700001
# High_mean_lag3               594.429871            26.700001
# High_std_lag7                594.429871            26.700001
# Low_mean_lag3                573.561707            26.700001
# Low_std_lag7                 573.561707            26.700001
# VWAP_mean_lag3               584.047913            26.700001
# VWAP_std_lag7                584.047913            26.700001
# month                                 1                    1
# day                                   3                    4
# day_of_week                           0                    1
#
# Date                         2000-01-05           2000-01-06  \
# Date                2000-01-05 00:00:00  2000-01-06 00:00:00
# Prev Close                        26.85                 26.3
# Open                               26.0                 25.8
# High                              27.75                 27.0
# Low                                25.5                 25.8
# Last                               26.4                 25.9
# Close                              26.3                25.95
# VWAP                              26.24                26.27
# Volume                           170100               102100
# Turnover                 446298000000.0       268173000000.0
# Trades                    115971.124044        115971.124044
# Deliverable Volume       1902423.307774       1902423.307774
# %Deliverble                    0.470017             0.470017
# Open_mean_lag3                    26.85            26.566668
# Open_std_lag7                     26.85            26.566668
# High_mean_lag3                27.700001            27.716667
# High_std_lag7                 27.700001            27.716667
# Low_mean_lag3                      26.6            26.233334
# Low_std_lag7                       26.6            26.233334
# VWAP_mean_lag3                26.969999            26.726667
# VWAP_std_lag7                 26.969999            26.726667
# month                                 1                    1
# day                                   5                    6
# day_of_week                           2                    3
#
# Date                         2000-01-07
# Date                2000-01-07 00:00:00
# Prev Close                        25.95
# Open                               25.0
# High                               26.0
# Low                               24.25
# Last                               25.0
# Close                              24.8
# VWAP                              25.04
# Volume                            62600
# Turnover                 156722000000.0
# Trades                    115971.124044
# Deliverable Volume       1902423.307774
# %Deliverble                    0.470017
# Open_mean_lag3                26.266666
# Open_std_lag7                 26.266666
# High_mean_lag3                27.816668
# High_std_lag7                 27.816668
# Low_mean_lag3                 25.933332
# Low_std_lag7                  25.933332
# VWAP_mean_lag3                26.583334
# VWAP_std_lag7                 26.583334
# month                                 1
# day                                   7
# day_of_week                           4

# %%
y_train = df_train['Close']
scaler = MinMaxScaler(feature_range=(0,1))
y_train1=scaler.fit_transform(np.array(df_train['Close']).reshape(-1,1))
y_trainn = df_train['Close'].to_numpy().reshape(-1,1)

# %%
y_valid = df_valid['Close']
scaler1 = MinMaxScaler(feature_range=(0,1))
y_valid1=scaler1.fit_transform(np.array(df_valid['Close']).reshape(-1,1))
y_validn = df_valid['Close'].to_numpy().reshape(-1,1)

# %%
X_train = df_train.drop(columns=['Close'])
X_train1 = X_train.drop('Date', axis =1)
X_train1 = (X_train1-X_train1.min())/(X_train1.max()-X_train1.min())
X_train2 = pd.concat((X_train1,X_train.Date), 1)

# %%
X_valid = df_valid.drop(columns=['Close'])
X_valid1 = X_valid.drop('Date', axis =1)
X_valid1 = (X_valid1-X_valid1.min())/(X_valid1.max()-X_valid1.min())
X_valid2 = pd.concat((X_valid1,X_valid.Date), 1)

# %%
X_train3 = X_train2.drop(columns=['Date']).to_numpy()
X_valid3 = X_valid2.drop(columns=['Date']).to_numpy()

# %%
y_train1= y_train1.reshape(-1,1)
y_valid1 = y_valid1.reshape(-1,1)

# %%
import xgboost as xgb
import sklearn
from xgboost import XGBRegressor
from xgboost import plot_importance

# %%
xgb = XGBRegressor(n_estimator=1000,learning_rate=0.0099,max_depth=15)
xgb

xgb.fit(X_train3,y_train1,
        eval_set = [(X_train3,y_train1),(X_valid3,y_valid1)],early_stopping_rounds=100,verbose=True)
# Out:
# [22:16:41] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimator" } are not used.
#
# [0]	validation_0-rmse:0.31985	validation_1-rmse:0.24471
# [1]	validation_0-rmse:0.31670	validation_1-rmse:0.24214
# [2]	validation_0-rmse:0.31357	validation_1-rmse:0.23959
# [3]	validation_0-rmse:0.31048	validation_1-rmse:0.23708
# [4]	validation_0-rmse:0.30742	validation_1-rmse:0.23458
# [5]	validation_0-rmse:0.30439	validation_1-rmse:0.23212
# [6]	validation_0-rmse:0.30139	validation_1-rmse:0.22968
# [7]	validation_0-rmse:0.29842	validation_1-rmse:0.22726
# [8]	validation_0-rmse:0.29548	validation_1-rmse:0.22490
# [9]	validation_0-rmse:0.29257	validation_1-rmse:0.22256
# [10]	validation_0-rmse:0.28968	validation_1-rmse:0.22024
# [11]	validation_0-rmse:0.28683	validation_1-rmse:0.21795
# [12]	validation_0-rmse:0.28400	validation_1-rmse:0.21569
# [13]	validation_0-rmse:0.28120	validation_1-rmse:0.21344
# [14]	validation_0-rmse:0.27843	validation_1-rmse:0.21121
# [15]	validation_0-rmse:0.27568	validation_1-rmse:0.20901
# [16]	validation_0-rmse:0.27297	validation_1-rmse:0.20684
# [17]	validation_0-rmse:0.27027	validation_1-rmse:0.20468
# [18]	validation_0-rmse:0.26761	validation_1-rmse:0.20254
# [19]	validation_0-rmse:0.26497	validation_1-rmse:0.20042
# [20]	validation_0-rmse:0.26236	validation_1-rmse:0.19842
# [21]	validation_0-rmse:0.25977	validation_1-rmse:0.19634
# [22]	validation_0-rmse:0.25721	validation_1-rmse:0.19428
# [23]	validation_0-rmse:0.25468	validation_1-rmse:0.19234
# [24]	validation_0-rmse:0.25217	validation_1-rmse:0.19042
# [25]	validation_0-rmse:0.24968	validation_1-rmse:0.18851
# [26]	validation_0-rmse:0.24722	validation_1-rmse:0.18653
# [27]	validation_0-rmse:0.24478	validation_1-rmse:0.18465
# [28]	validation_0-rmse:0.24237	validation_1-rmse:0.18271
# [29]	validation_0-rmse:0.23998	validation_1-rmse:0.18079
# [30]	validation_0-rmse:0.23762	validation_1-rmse:0.17904
# [31]	validation_0-rmse:0.23527	validation_1-rmse:0.17729
# [32]	validation_0-rmse:0.23295	validation_1-rmse:0.17557
# [33]	validation_0-rmse:0.23066	validation_1-rmse:0.17386
# [34]	validation_0-rmse:0.22839	validation_1-rmse:0.17216
# [35]	validation_0-rmse:0.22613	validation_1-rmse:0.17034
# [36]	validation_0-rmse:0.22391	validation_1-rmse:0.16868
# [37]	validation_0-rmse:0.22170	validation_1-rmse:0.16688
# [38]	validation_0-rmse:0.21951	validation_1-rmse:0.16512
# [39]	validation_0-rmse:0.21735	validation_1-rmse:0.16351
# [40]	validation_0-rmse:0.21521	validation_1-rmse:0.16178
# [41]	validation_0-rmse:0.21308	validation_1-rmse:0.16020
# [42]	validation_0-rmse:0.21098	validation_1-rmse:0.15863
# [43]	validation_0-rmse:0.20890	validation_1-rmse:0.15694
# [44]	validation_0-rmse:0.20685	validation_1-rmse:0.15541
# [45]	validation_0-rmse:0.20481	validation_1-rmse:0.15376
# [46]	validation_0-rmse:0.20279	validation_1-rmse:0.15226
# [47]	validation_0-rmse:0.20079	validation_1-rmse:0.15072
# [48]	validation_0-rmse:0.19881	validation_1-rmse:0.14912
# [49]	validation_0-rmse:0.19685	validation_1-rmse:0.14766
# [50]	validation_0-rmse:0.19491	validation_1-rmse:0.14621
# [51]	validation_0-rmse:0.19299	validation_1-rmse:0.14466
# [52]	validation_0-rmse:0.19109	validation_1-rmse:0.14324
# [53]	validation_0-rmse:0.18920	validation_1-rmse:0.14184
# [54]	validation_0-rmse:0.18734	validation_1-rmse:0.14034
# [55]	validation_0-rmse:0.18549	validation_1-rmse:0.13885
# [56]	validation_0-rmse:0.18366	validation_1-rmse:0.13748
# [57]	validation_0-rmse:0.18185	validation_1-rmse:0.13613
# [58]	validation_0-rmse:0.18006	validation_1-rmse:0.13467
# [59]	validation_0-rmse:0.17829	validation_1-rmse:0.13335
# [60]	validation_0-rmse:0.17653	validation_1-rmse:0.13205
# [61]	validation_0-rmse:0.17479	validation_1-rmse:0.13064
# [62]	validation_0-rmse:0.17307	validation_1-rmse:0.12936
# [63]	validation_0-rmse:0.17136	validation_1-rmse:0.12798
# [64]	validation_0-rmse:0.16967	validation_1-rmse:0.12668
# [65]	validation_0-rmse:0.16800	validation_1-rmse:0.12546
# [66]	validation_0-rmse:0.16634	validation_1-rmse:0.12413
# [67]	validation_0-rmse:0.16470	validation_1-rmse:0.12278
# [68]	validation_0-rmse:0.16308	validation_1-rmse:0.12146
# [69]	validation_0-rmse:0.16147	validation_1-rmse:0.12030
# [70]	validation_0-rmse:0.15988	validation_1-rmse:0.11902
# [71]	validation_0-rmse:0.15831	validation_1-rmse:0.11788
# [72]	validation_0-rmse:0.15675	validation_1-rmse:0.11673
# [73]	validation_0-rmse:0.15520	validation_1-rmse:0.11560
# [74]	validation_0-rmse:0.15367	validation_1-rmse:0.11437
# [75]	validation_0-rmse:0.15216	validation_1-rmse:0.11314
# [76]	validation_0-rmse:0.15066	validation_1-rmse:0.11206
# [77]	validation_0-rmse:0.14917	validation_1-rmse:0.11098
# [78]	validation_0-rmse:0.14770	validation_1-rmse:0.10985
# [79]	validation_0-rmse:0.14625	validation_1-rmse:0.10868
# [80]	validation_0-rmse:0.14481	validation_1-rmse:0.10766
# [81]	validation_0-rmse:0.14338	validation_1-rmse:0.10664
# [82]	validation_0-rmse:0.14197	validation_1-rmse:0.10551
# [83]	validation_0-rmse:0.14057	validation_1-rmse:0.10450
# [84]	validation_0-rmse:0.13918	validation_1-rmse:0.10339
# [85]	validation_0-rmse:0.13781	validation_1-rmse:0.10242
# [86]	validation_0-rmse:0.13645	validation_1-rmse:0.10141
# [87]	validation_0-rmse:0.13511	validation_1-rmse:0.10045
# [88]	validation_0-rmse:0.13378	validation_1-rmse:0.09938
# [89]	validation_0-rmse:0.13246	validation_1-rmse:0.09841
# [90]	validation_0-rmse:0.13115	validation_1-rmse:0.09740
# [91]	validation_0-rmse:0.12986	validation_1-rmse:0.09642
# [92]	validation_0-rmse:0.12858	validation_1-rmse:0.09539
# [93]	validation_0-rmse:0.12732	validation_1-rmse:0.09448
# [94]	validation_0-rmse:0.12606	validation_1-rmse:0.09348
# [95]	validation_0-rmse:0.12482	validation_1-rmse:0.09248
# [96]	validation_0-rmse:0.12359	validation_1-rmse:0.09153
# [97]	validation_0-rmse:0.12237	validation_1-rmse:0.09067
# [98]	validation_0-rmse:0.12117	validation_1-rmse:0.08970
# [99]	validation_0-rmse:0.11997	validation_1-rmse:0.08879
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.0099, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=15, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimator=1000, n_estimators=100,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', ...)

# %%
xgb = XGBRegressor(n_estimator=1000,learning_rate=0.01)
xgb
xgb.fit(X_train3,y_train1,eval_set=[(X_train3,y_train1),(X_valid3,y_valid1)],early_stopping_rounds=100,verbose=True)
# Out:
# [22:16:41] WARNING: C:/buildkite-agent/builds/buildkite-windows-cpu-autoscaling-group-i-03de431ba26204c4d-1/xgboost/xgboost-ci-windows/src/learner.cc:767:
# Parameters: { "n_estimator" } are not used.
#
# [0]	validation_0-rmse:0.31982	validation_1-rmse:0.24468
# [1]	validation_0-rmse:0.31663	validation_1-rmse:0.24209
# [2]	validation_0-rmse:0.31348	validation_1-rmse:0.23952
# [3]	validation_0-rmse:0.31036	validation_1-rmse:0.23697
# [4]	validation_0-rmse:0.30727	validation_1-rmse:0.23446
# [5]	validation_0-rmse:0.30421	validation_1-rmse:0.23197
# [6]	validation_0-rmse:0.30118	validation_1-rmse:0.22950
# [7]	validation_0-rmse:0.29818	validation_1-rmse:0.22706
# [8]	validation_0-rmse:0.29521	validation_1-rmse:0.22468
# [9]	validation_0-rmse:0.29227	validation_1-rmse:0.22232
# [10]	validation_0-rmse:0.28936	validation_1-rmse:0.21998
# [11]	validation_0-rmse:0.28648	validation_1-rmse:0.21767
# [12]	validation_0-rmse:0.28363	validation_1-rmse:0.21537
# [13]	validation_0-rmse:0.28080	validation_1-rmse:0.21311
# [14]	validation_0-rmse:0.27801	validation_1-rmse:0.21087
# [15]	validation_0-rmse:0.27524	validation_1-rmse:0.20865
# [16]	validation_0-rmse:0.27250	validation_1-rmse:0.20645
# [17]	validation_0-rmse:0.26979	validation_1-rmse:0.20427
# [18]	validation_0-rmse:0.26710	validation_1-rmse:0.20212
# [19]	validation_0-rmse:0.26444	validation_1-rmse:0.19998
# [20]	validation_0-rmse:0.26181	validation_1-rmse:0.19797
# [21]	validation_0-rmse:0.25920	validation_1-rmse:0.19586
# [22]	validation_0-rmse:0.25662	validation_1-rmse:0.19389
# [23]	validation_0-rmse:0.25406	validation_1-rmse:0.19184
# [24]	validation_0-rmse:0.25154	validation_1-rmse:0.18981
# [25]	validation_0-rmse:0.24903	validation_1-rmse:0.18789
# [26]	validation_0-rmse:0.24655	validation_1-rmse:0.18589
# [27]	validation_0-rmse:0.24410	validation_1-rmse:0.18392
# [28]	validation_0-rmse:0.24167	validation_1-rmse:0.18211
# [29]	validation_0-rmse:0.23926	validation_1-rmse:0.18033
# [30]	validation_0-rmse:0.23688	validation_1-rmse:0.17850
# [31]	validation_0-rmse:0.23452	validation_1-rmse:0.17669
# [32]	validation_0-rmse:0.23218	validation_1-rmse:0.17495
# [33]	validation_0-rmse:0.22987	validation_1-rmse:0.17323
# [34]	validation_0-rmse:0.22758	validation_1-rmse:0.17153
# [35]	validation_0-rmse:0.22532	validation_1-rmse:0.16978
# [36]	validation_0-rmse:0.22307	validation_1-rmse:0.16797
# [37]	validation_0-rmse:0.22085	validation_1-rmse:0.16632
# [38]	validation_0-rmse:0.21865	validation_1-rmse:0.16453
# [39]	validation_0-rmse:0.21648	validation_1-rmse:0.16291
# [40]	validation_0-rmse:0.21432	validation_1-rmse:0.16131
# [41]	validation_0-rmse:0.21219	validation_1-rmse:0.15958
# [42]	validation_0-rmse:0.21007	validation_1-rmse:0.15800
# [43]	validation_0-rmse:0.20798	validation_1-rmse:0.15644
# [44]	validation_0-rmse:0.20591	validation_1-rmse:0.15476
# [45]	validation_0-rmse:0.20386	validation_1-rmse:0.15324
# [46]	validation_0-rmse:0.20183	validation_1-rmse:0.15159
# [47]	validation_0-rmse:0.19982	validation_1-rmse:0.15009
# [48]	validation_0-rmse:0.19783	validation_1-rmse:0.14856
# [49]	validation_0-rmse:0.19586	validation_1-rmse:0.14697
# [50]	validation_0-rmse:0.19391	validation_1-rmse:0.14552
# [51]	validation_0-rmse:0.19198	validation_1-rmse:0.14395
# [52]	validation_0-rmse:0.19007	validation_1-rmse:0.14253
# [53]	validation_0-rmse:0.18818	validation_1-rmse:0.14113
# [54]	validation_0-rmse:0.18631	validation_1-rmse:0.13962
# [55]	validation_0-rmse:0.18445	validation_1-rmse:0.13823
# [56]	validation_0-rmse:0.18261	validation_1-rmse:0.13674
# [57]	validation_0-rmse:0.18080	validation_1-rmse:0.13538
# [58]	validation_0-rmse:0.17900	validation_1-rmse:0.13393
# [59]	validation_0-rmse:0.17721	validation_1-rmse:0.13249
# [60]	validation_0-rmse:0.17545	validation_1-rmse:0.13118
# [61]	validation_0-rmse:0.17370	validation_1-rmse:0.12973
# [62]	validation_0-rmse:0.17197	validation_1-rmse:0.12834
# [63]	validation_0-rmse:0.17026	validation_1-rmse:0.12695
# [64]	validation_0-rmse:0.16857	validation_1-rmse:0.12572
# [65]	validation_0-rmse:0.16689	validation_1-rmse:0.12447
# [66]	validation_0-rmse:0.16523	validation_1-rmse:0.12313
# [67]	validation_0-rmse:0.16358	validation_1-rmse:0.12194
# [68]	validation_0-rmse:0.16195	validation_1-rmse:0.12062
# [69]	validation_0-rmse:0.16034	validation_1-rmse:0.11946
# [70]	validation_0-rmse:0.15875	validation_1-rmse:0.11828
# [71]	validation_0-rmse:0.15717	validation_1-rmse:0.11701
# [72]	validation_0-rmse:0.15560	validation_1-rmse:0.11587
# [73]	validation_0-rmse:0.15405	validation_1-rmse:0.11475
# [74]	validation_0-rmse:0.15252	validation_1-rmse:0.11351
# [75]	validation_0-rmse:0.15100	validation_1-rmse:0.11242
# [76]	validation_0-rmse:0.14950	validation_1-rmse:0.11132
# [77]	validation_0-rmse:0.14801	validation_1-rmse:0.11012
# [78]	validation_0-rmse:0.14654	validation_1-rmse:0.10902
# [79]	validation_0-rmse:0.14508	validation_1-rmse:0.10784
# [80]	validation_0-rmse:0.14363	validation_1-rmse:0.10681
# [81]	validation_0-rmse:0.14220	validation_1-rmse:0.10567
# [82]	validation_0-rmse:0.14079	validation_1-rmse:0.10466
# [83]	validation_0-rmse:0.13939	validation_1-rmse:0.10354
# [84]	validation_0-rmse:0.13800	validation_1-rmse:0.10253
# [85]	validation_0-rmse:0.13663	validation_1-rmse:0.10147
# [86]	validation_0-rmse:0.13527	validation_1-rmse:0.10043
# [87]	validation_0-rmse:0.13392	validation_1-rmse:0.09940
# [88]	validation_0-rmse:0.13259	validation_1-rmse:0.09833
# [89]	validation_0-rmse:0.13127	validation_1-rmse:0.09739
# [90]	validation_0-rmse:0.12996	validation_1-rmse:0.09638
# [91]	validation_0-rmse:0.12867	validation_1-rmse:0.09534
# [92]	validation_0-rmse:0.12739	validation_1-rmse:0.09443
# [93]	validation_0-rmse:0.12612	validation_1-rmse:0.09341
# [94]	validation_0-rmse:0.12486	validation_1-rmse:0.09252
# [95]	validation_0-rmse:0.12362	validation_1-rmse:0.09162
# [96]	validation_0-rmse:0.12239	validation_1-rmse:0.09063
# [97]	validation_0-rmse:0.12117	validation_1-rmse:0.08973
# [98]	validation_0-rmse:0.11997	validation_1-rmse:0.08888
# [99]	validation_0-rmse:0.11877	validation_1-rmse:0.08796
# XGBRegressor(base_score=0.5, booster='gbtree', callbacks=None,
#              colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#              early_stopping_rounds=None, enable_categorical=False,
#              eval_metric=None, feature_types=None, gamma=0, gpu_id=-1,
#              grow_policy='depthwise', importance_type=None,
#              interaction_constraints='', learning_rate=0.01, max_bin=256,
#              max_cat_threshold=64, max_cat_to_onehot=4, max_delta_step=0,
#              max_depth=6, max_leaves=0, min_child_weight=1, missing=nan,
#              monotone_constraints='()', n_estimator=1000, n_estimators=100,
#              n_jobs=0, num_parallel_tree=1, predictor='auto', ...)

# %%
plt.figure(figsize=(12,8))
feature_importance = plot_importance(xgb, height=0.9)
feature_importance
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %%
predicted_results_v = xgb.predict(X_valid3)
predicted_results_t = xgb.predict(X_train3)
predicted_results_v = predicted_results_v.reshape(-1,1)
predicted_results_t = predicted_results_t.reshape(-1,1)
predicted_results_v = scaler1.inverse_transform(predicted_results_v)
predicted_results_t = scaler.inverse_transform(predicted_results_t)

# %%
plt.figure(figsize=(20,15))
plt.plot(X_train2.index,list(y_trainn),label= ' Actual Price train',color='b')
plt.plot(X_train2.index,list(predicted_results_t),label= ' Predicted Price train',color='r')
plt.plot(X_valid2.index,list(y_validn),label= ' Actual Price valid',color='m')
plt.plot(X_valid2.index,list(predicted_results_v),label= ' Predicted Price valid',color='g')


plt.xlabel('Date')
plt.ylabel('Nifty 50 Closing Price')
plt.legend()
plt.show()

# %% [markdown]
# # Conclusions: Here we can accurately predict the stocks and also learn how to make machine learning model on the stock prediictions.
